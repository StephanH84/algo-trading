# %%
import os
import zipfile

# %%
PATH = "../files/data"
for file in os.listdir(PATH):
    print(file)
    file_path = PATH + "/" + file
    if ".zip" in file:
        with zipfile.ZipFile(file_path,"r") as zip_ref:
            zip_ref.extractall(PATH)
# Out:
# DAT_XLSX_EURUSD_M1_201809.xlsx
# HISTDATA_COM_XLSX_AUDJPY_M12002.zip
# HISTDATA_COM_XLSX_AUDJPY_M12003.zip
# HISTDATA_COM_XLSX_AUDJPY_M12004.zip
# HISTDATA_COM_XLSX_AUDJPY_M12005.zip
# HISTDATA_COM_XLSX_AUDJPY_M12006.zip
# HISTDATA_COM_XLSX_AUDJPY_M12007.zip
# HISTDATA_COM_XLSX_AUDJPY_M12008.zip
# HISTDATA_COM_XLSX_AUDJPY_M12009.zip
# HISTDATA_COM_XLSX_AUDJPY_M12010.zip
# HISTDATA_COM_XLSX_AUDJPY_M12011.zip
# HISTDATA_COM_XLSX_AUDJPY_M12012.zip
# HISTDATA_COM_XLSX_AUDJPY_M12013.zip
# HISTDATA_COM_XLSX_AUDJPY_M12014.zip
# HISTDATA_COM_XLSX_AUDJPY_M12015.zip
# HISTDATA_COM_XLSX_AUDJPY_M12016.zip
# HISTDATA_COM_XLSX_AUDJPY_M12017.zip
# HISTDATA_COM_XLSX_AUDNZD_M12007.zip
# HISTDATA_COM_XLSX_AUDNZD_M12008.zip
# HISTDATA_COM_XLSX_AUDNZD_M12009.zip
# HISTDATA_COM_XLSX_AUDNZD_M12010.zip
# HISTDATA_COM_XLSX_AUDNZD_M12011.zip
# HISTDATA_COM_XLSX_AUDNZD_M12012.zip
# HISTDATA_COM_XLSX_AUDNZD_M12013.zip
# HISTDATA_COM_XLSX_AUDNZD_M12014.zip
# HISTDATA_COM_XLSX_AUDNZD_M12015.zip
# ...
